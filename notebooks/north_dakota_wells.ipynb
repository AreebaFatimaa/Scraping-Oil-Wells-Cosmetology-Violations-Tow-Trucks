# %%
# Install Playwright (if not already installed)
# !pip install playwright

# Install the browsers
# !playwright install firefox
# Out:
# Requirement already satisfied: playwright in /Users/towcenter/.pyenv/versions/3.13.9/lib/python3.13/site-packages (1.56.0)
# Requirement already satisfied: pyee<14,>=13 in /Users/towcenter/.pyenv/versions/3.13.9/lib/python3.13/site-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/towcenter/.pyenv/versions/3.13.9/lib/python3.13/site-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in /Users/towcenter/.pyenv/versions/3.13.9/lib/python3.13/site-packages (from pyee<14,>=13->playwright) (4.15.0)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from playwright.async_api import async_playwright

async def open_site():
    global playwright, browser, context, page

    playwright = await async_playwright().start()
    browser = await playwright.firefox.launch(headless=False)
    context = await browser.new_context()
    page = await context.new_page()

    print("Opening page…")
    await page.goto("https://www.dmr.nd.gov/oilgas/findwellsvw.asp", wait_until="networkidle")
    print("Page loaded. Browser should be visible.")

await open_site()
# Out:
# Opening page…
# Page loaded. Browser should be visible.

# %%
import pandas as pd
from tqdm.notebook import tqdm

all_rows = []
townships = list(range(129, 165))  # 129 to 164 inclusive

for ts in tqdm(townships, desc="Scraping townships"):
    # Open a fresh page for each township
    page2 = await context.new_page()
    await page2.goto("https://www.dmr.nd.gov/oilgas/findwellsvw.asp", wait_until="networkidle")

    print(f"Selecting township {ts}…")
    await page2.select_option("#ddmTownship", str(ts))
    await page2.click("input[name='B1']")

    await page2.wait_for_load_state("networkidle")

    table = await page2.query_selector("table[summary='Well Log search results table']")
    if table is None:
        print(f"No table found for township {ts}, skipping.")
        await page2.close()
        continue

    # Get headers once
    if 'headers' not in locals():
        header_elements = await table.query_selector_all("th")
        headers = [await th.inner_text() for th in header_elements]
        print("Column headers:", headers)

    # Get rows
    row_elements = await table.query_selector_all("tr")
    for tr in row_elements[1:]:
        cell_elements = await tr.query_selector_all("td")
        row = [await td.inner_text() for td in cell_elements]
        all_rows.append(row)

    print(f"Township {ts} done. Collected {len(row_elements)-1} rows.")
    await page2.close()  # close page to avoid target closed issues

print("\nScraping complete. Total rows collected:", len(all_rows))

# Convert to DataFrame
df = pd.DataFrame(all_rows, columns=headers)
df.head()
# Out:
# Scraping townships:   0%|          | 0/36 [00:00<?, ?it/s]
# Selecting township 129…
# Column headers: ['File No', 'CTB No', 'API No', 'Well Type', 'Well Status', 'Status Date', 'DTD', 'Location', 'Operator', 'Well Name', 'Field']
# Township 129 done. Collected 378 rows.
# Selecting township 130…
# Township 130 done. Collected 599 rows.
# Selecting township 131…
# Township 131 done. Collected 474 rows.
# Selecting township 132…
# Township 132 done. Collected 215 rows.
# Selecting township 133…
# Township 133 done. Collected 166 rows.
# Selecting township 134…
# Township 134 done. Collected 124 rows.
# Selecting township 135…
# Township 135 done. Collected 103 rows.
# Selecting township 136…
# Township 136 done. Collected 98 rows.
# Selecting township 137…
# Township 137 done. Collected 118 rows.
# Selecting township 138…
# Township 138 done. Collected 215 rows.
# Selecting township 139…
# Township 139 done. Collected 631 rows.
# Selecting township 140…
# Township 140 done. Collected 683 rows.
# Selecting township 141…
# Township 141 done. Collected 475 rows.
# Selecting township 142…
# Township 142 done. Collected 667 rows.
# Selecting township 143…
# Township 143 done. Collected 699 rows.
# Selecting township 144…
# Township 144 done. Collected 824 rows.
# Selecting township 145…
# Township 145 done. Collected 1020 rows.
# Selecting township 146…
# Township 146 done. Collected 1316 rows.
# Selecting township 147…
# Township 147 done. Collected 1399 rows.
# Selecting township 148…
# Township 148 done. Collected 1625 rows.
# Selecting township 149…
# Township 149 done. Collected 2083 rows.
# Selecting township 150…
# Township 150 done. Collected 2316 rows.
# Selecting township 151…
# Township 151 done. Collected 2774 rows.
# Selecting township 152…
# Township 152 done. Collected 3211 rows.
# Selecting township 153…
# Township 153 done. Collected 3000 rows.
# Selecting township 154…
# Township 154 done. Collected 2458 rows.
# Selecting township 155…
# Township 155 done. Collected 2424 rows.
# Selecting township 156…
# Township 156 done. Collected 1849 rows.
# Selecting township 157…
# Township 157 done. Collected 1382 rows.
# Selecting township 158…
# Township 158 done. Collected 1683 rows.
# Selecting township 159…
# Township 159 done. Collected 1151 rows.
# Selecting township 160…
# Township 160 done. Collected 1266 rows.
# Selecting township 161…
# Township 161 done. Collected 1611 rows.
# Selecting township 162…
# Township 162 done. Collected 1469 rows.
# Selecting township 163…
# Township 163 done. Collected 2114 rows.
# Selecting township 164…
# Township 164 done. Collected 566 rows.
#
# Scraping complete. Total rows collected: 43186
#   File No CTB No      API No Well Type Well Status Status Date   DTD  \
# 0    3065         3308100001        OG         DRY    1/1/1962  1214
# 1   99025         3302199025        ST         DRY   9/30/1963  1600
# 2     515         3302100001        OG         DRY  11/17/1954  1882
# 3     572         3302100002        OG         DRY   6/17/1954  1860
# 4    1394         3302100005        OG         DRY   3/12/1957  3166
#
#          Location                   Operator        Well Name    Field
# 0   NWNW 9-129-58      SARGENT MINERAL CORP.        LAMPORT 1  WILDCAT
# 1  NENE 10-129-63  JACK ROUSE OIL PROPERTIES  HAROLD BILLIE 1  WILDCAT
# 2  SENW 11-129-63    H. HANSON OIL SYNDICATE  HAROLD BILLEY 1  WILDCAT
# 3  NENW 14-129-63    H. HANSON OIL SYNDICATE      JOHN BELL 1  WILDCAT
# 4  NWNW 22-129-66     CALVERT DRILLING, INC.    MARVIN KAMM 1  WILDCAT

# %%
# Save the DataFrame to CSV
csv_filename = "north_dakota_wells.csv"
df.to_csv(csv_filename, index=False)

print(f"Data saved to {csv_filename}")
# Out:
# Data saved to north_dakota_wells.csv
